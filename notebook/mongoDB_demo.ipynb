# %%
# We will  send the data in Mogodb
import pandas as pd
import pymongo

df = pd.read_csv('data.csv')
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
# df should be converted into dict before we push it to mongodb

data = df.to_dict(orient='records')
# data

# %%
DB_NAME = "Vehicle Insurance"
COLLECTION_NAME = "Vehicle Insurance-Data"
CONNECTION_URL = "mongodb+srv://PrinceShah:vaLTrJ4kqfBjJ71q@cluster0.p5vhzth.mongodb.net/?appName=Cluster0"

# above, either remove your credentials or delete the mongoDB resource bofore pushing it to github.

# %%
import pymongo

# Connect to MongoDB
client = pymongo.MongoClient(CONNECTION_URL)

# Access database
data_base = client[DB_NAME]

# Access collection
collection = data_base[COLLECTION_NAME]
# Out:
# ---------------------------------------------------------------------------
# InvalidName                               Traceback (most recent call last)
# Cell In[7], line 2
#       1 client = pymongo.MongoClient(CONNECTION_URL)
# ----> 2 data_base = client[DB_NAME]
#       3 collection = data_base[COLLECTION_NAME]
#
# File c:\Users\princ\MLOPS\MLOPS-Project-1\venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:1347, in MongoClient.__getitem__(self, name)
#    1339 def __getitem__(self, name: str) -> database.Database[_DocumentType]:
#    1340     """Get a database by name.
#    1341
#    1342     Raises :class:`~pymongo.errors.InvalidName` if an invalid
#    (...)   1345     :param name: the name of the database to get
#    1346     """
# -> 1347     return database.Database(self, name)
#
# File c:\Users\princ\MLOPS\MLOPS-Project-1\venv\Lib\site-packages\pymongo\synchronous\database.py:133, in Database.__init__(self, client, name, codec_options, read_preference, write_concern, read_concern)
#     130         raise TypeError(f"MongoClient required but given {type(client).__name__}")
#     132 if name != "$external":
# --> 133     _check_name(name)
#     135 self._name = name
#     136 self._client: MongoClient[_DocumentType] = client
#
# File c:\Users\princ\MLOPS\MLOPS-Project-1\venv\Lib\site-packages\pymongo\database_shared.py:31, in _check_name(name)
#      29 for invalid_char in [" ", ".", "$", "/", "\\", "\x00", '"']:
#      30     if invalid_char in name:
# ---> 31         raise InvalidName("database names cannot contain the character %r" % invalid_char)
#
# InvalidName: database names cannot contain the character ' '
